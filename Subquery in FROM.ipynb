# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Subquery in FROM

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Description

# %% [markdown]
# In this lesson we will use a subquery like a temporary table, meaning we will do a calculation, and then reference the result of that calculation in another query.

# %% [markdown]
# ## Learning objectives
#
# In this train we will learn:
# - How to create a query using the FROM clause.

# %% [markdown]
# ## Connecting to our MySQL database
#
# Using our `Access_to_Basic_Services` table in our `united_nations` database we created in MySQL Workbench, we want to answer some questions about our dataset. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.
#
# Note that before, for this tutorial, we will already have worked through the lessons where the `united_nations.Basic_Services` table, `united_nations.Economic_Indicators` table, and the `united_nations.Geographic_Locations` table have been created.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql
# Out:
# c:\Users\PC\anaconda3\envs\DS_Python\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:20!_Ke&Y@localhost:3306/united_nations

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line then the query like below, and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %% [markdown]
# ## Exercise

# %% [markdown]
# In this exercise. We will use a subquery to answer the following question: What is the average GDP and population for countries with unemployment rates above 5%?

# %% [markdown]
# ### Creating the subquery
# Construct the subquery that displays the average GDP and average population of countries for 2020. The query should have the following columns: `Country_name`, `Avg_GDP`, `Avg_Population`.

# %%
# %%sql
#
# SELECT Country_name,
#     Est_gdp_in_billions,
#     Est_population_in_millions
# FROM Economic_Indicators
# WHERE Pct_unemployment > 5
#     AND Time_period = 2020;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 37 rows affected.
# [('Afghanistan', Decimal('20.1400'), 39),
#  ('Argentina', Decimal('385.5400'), 45),
#  ('Armenia', Decimal('12.6400'), 3),
#  ('Australia', Decimal('1326.9000'), 26),
#  ('Azerbaijan', Decimal('42.6900'), 10),
#  ('Bhutan', Decimal('2.3300'), 1),
#  ('Botswana', Decimal('14.9300'), 3),
#  ('Brazil', Decimal('1448.5600'), 213),
#  ('Brunei Darussalam', Decimal('12.0100'), 0),
#  ('Canada', Decimal('1645.4200'), 38),
#  ('Chile', Decimal('252.7300'), 19),
#  ('China', Decimal('14687.6700'), 1411),
#  ('Colombia', Decimal('270.3000'), 51),
#  ('Costa Rica', Decimal('62.1600'), 5),
#  ('Cyprus', Decimal('25.0100'), 1),
#  ('Dominican Republic', Decimal('78.8400'), 11),
#  ('Ecuador', Decimal('99.2900'), 18),
#  ('El Salvador', Decimal('24.5600'), 6),
#  ('Georgia', Decimal('15.8400'), 4),
#  ('Honduras', Decimal('23.8300'), 10),
#  ('India', Decimal('2667.6900'), 1396),
#  ('Jamaica', Decimal('13.8100'), 3),
#  ('Jordan', Decimal('44.1800'), 11),
#  ('Kiribati', Decimal('0.1800'), 0),
#  ('Mauritius', Decimal('11.4000'), 1),
#  ('Mongolia', Decimal('13.3100'), 3),
#  ('New Caledonia', Decimal('9.4400'), 0),
#  ('Panama', Decimal('53.9800'), 4),
#  ('Paraguay', Decimal('35.4300'), 7),
#  ('Peru', Decimal('201.7100'), 33),
#  ('Rwanda', Decimal('10.1800'), 13),
#  ('Saudi Arabia', Decimal('703.3700'), 36),
#  ('South Africa', Decimal('337.6200'), 59),
#  ('Sri Lanka', Decimal('85.3500'), 22),
#  ('Uruguay', Decimal('53.5600'), 3),
#  ('Uzbekistan', Decimal('59.8900'), 34),
#  ('Zambia', Decimal('18.1100'), 19)]

# %% [markdown]
# ### Creating the main query
# Construct a query that filters out countries with unemployment rates above 5%. The query should include the following columns: `Country_name`, `Est_gdp_in_billions`,  `Est_population_in_millions`.

# %%
# %%sql
#
# SELECT Country_name,
#     AVG(Est_gdp_in_billions) AS Avg_GDP,
#     AVG(Est_population_in_millions) As Avg_Population
# FROM Economic_Indicators
# GROUP BY Country_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 182 rows affected.
# [('Afghanistan', Decimal('19.06333333'), Decimal('36.5000')),
#  ('Algeria', Decimal('164.63333333'), Decimal('41.5000')),
#  ('American Samoa', Decimal('0.66000000'), Decimal('0.0000')),
#  ('Angola', Decimal('67.79166667'), Decimal('30.5000')),
#  ('Anguilla', None, None),
#  ('Antigua and Barbuda', Decimal('1.41666667'), Decimal('0.0000')),
#  ('Argentina', Decimal('525.67000000'), Decimal('44.1667')),
#  ('Armenia', Decimal('11.89166667'), Decimal('3.0000')),
#  ('Aruba', Decimal('2.97000000'), Decimal('0.0000')),
#  ('Australia', Decimal('1338.51666667'), Decimal('24.8333')),
#  ('Azerbaijan', Decimal('44.96333333'), Decimal('10.0000')),
#  ('Bahamas', None, None),
#  ('Bahrain', Decimal('34.98666667'), Decimal('1.0000')),
#  ('Bangladesh', Decimal('300.09833333'), Decimal('162.8333')),
#  ('Barbados', Decimal('4.93666667'), Decimal('0.0000')),
#  ('Belize', Decimal('2.26166667'), Decimal('0.0000')),
#  ('Benin', Decimal('13.36833333'), Decimal('11.8333')),
#  ('Bermuda', Decimal('7.03833333'), Decimal('0.0000')),
#  ('Bhutan', Decimal('2.32166667'), Decimal('1.0000')),
#  ('Bolivia (Plurinational State of)', None, None),
#  ('Botswana', Decimal('15.56333333'), Decimal('2.1667')),
#  ('Brazil', Decimal('1816.70000000'), Decimal('209.3333')),
#  ('British Virgin Islands', None, Decimal('0.0000')),
#  ('Brunei Darussalam', Decimal('12.58500000'), Decimal('0.0000')),
#  ('Burkina Faso', Decimal('14.79500000'), Decimal('20.1667')),
#  ('Burundi', Decimal('2.72333333'), Decimal('11.3333')),
#  ('Cabo Verde', Decimal('1.78000000'), Decimal('1.0000')),
#  ('Cambodia', Decimal('22.96333333'), Decimal('15.8333')),
#  ('Cameroon', Decimal('37.08833333'), Decimal('24.6667')),
#  ('Canada', Decimal('1641.09000000'), Decimal('37.0000')),
#  ('Cayman Islands', Decimal('4.81000000'), Decimal('0.0000')),
#  ('Central African Republic', Decimal('2.06166667'), Decimal('5.0000')),
#  ('Chad', Decimal('10.72000000'), Decimal('15.5000')),
#  ('Chile', Decimal('265.81166667'), Decimal('18.5000')),
#  ('China', Decimal('12911.27833333'), Decimal('1397.6667')),
#  ('Colombia', Decimal('302.63333333'), Decimal('48.8333')),
#  ('Comoros', Decimal('1.09000000'), Decimal('1.0000')),
#  ('Congo', None, None),
#  ('Cook Islands', None, None),
#  ('Costa Rica', Decimal('60.80166667'), Decimal('5.0000')),
#  ("Côte d'Ivoire", None, None),
#  ('Cuba', Decimal('97.69666667'), Decimal('11.0000')),
#  ('Curaçao', None, None),
#  ('Cyprus', Decimal('23.41000000'), Decimal('1.0000')),
#  ("Democratic People's Republic of Korea", None, None),
#  ('Democratic Republic of the Congo', None, None),
#  ('Djibouti', Decimal('2.82666667'), Decimal('1.0000')),
#  ('Dominica', Decimal('0.54666667'), Decimal('0.0000')),
#  ('Dominican Republic', Decimal('80.03333333'), Decimal('10.8333')),
#  ('Ecuador', Decimal('103.08166667'), Decimal('16.8333')),
#  ('Egypt', None, None),
#  ('El Salvador', Decimal('25.01166667'), Decimal('6.0000')),
#  ('Equatorial Guinea', Decimal('12.21000000'), Decimal('1.0000')),
#  ('Eritrea', None, Decimal('3.0000')),
#  ('Eswatini', Decimal('4.23833333'), Decimal('1.0000')),
#  ('Ethiopia', Decimal('84.75000000'), Decimal('109.5000')),
#  ('Falkland Islands (Malvinas)', None, None),
#  ('Fiji', Decimal('5.08333333'), Decimal('1.0000')),
#  ('French Guiana', None, None),
#  ('French Polynesia', Decimal('5.75166667'), Decimal('0.0000')),
#  ('Gabon', Decimal('15.39666667'), Decimal('2.0000')),
#  ('Gambia', None, None),
#  ('Georgia', Decimal('16.20666667'), Decimal('4.0000')),
#  ('Ghana', Decimal('61.94500000'), Decimal('30.6667')),
#  ('Greenland', Decimal('2.86500000'), Decimal('0.0000')),
#  ('Grenada', Decimal('1.06333333'), Decimal('0.0000')),
#  ('Guadeloupe', None, None),
#  ('Guam', Decimal('6.00500000'), Decimal('0.0000')),
#  ('Guatemala', Decimal('71.33666667'), Decimal('16.3333')),
#  ('Guinea', Decimal('11.19833333'), Decimal('12.5000')),
#  ('Guinea-Bissau', Decimal('1.32500000'), Decimal('2.0000')),
#  ('Guyana', Decimal('4.82333333'), Decimal('1.0000')),
#  ('Haiti', Decimal('14.93666667'), Decimal('11.0000')),
#  ('Honduras', Decimal('23.13833333'), Decimal('9.6667')),
#  ('India', Decimal('2542.00500000'), Decimal('1360.6667')),
#  ('Indonesia', Decimal('1004.73500000'), Decimal('265.6667')),
#  ('Iran (Islamic Republic of)', None, None),
#  ('Iraq', Decimal('194.32833333'), Decimal('40.5000')),
#  ('Israel', Decimal('362.69833333'), Decimal('8.8333')),
#  ('Jamaica', Decimal('14.74166667'), Decimal('3.0000')),
#  ('Japan', Decimal('4930.12000000'), Decimal('126.8333')),
#  ('Jordan', Decimal('42.10500000'), Decimal('10.1667')),
#  ('Kazakhstan', Decimal('170.09500000'), Decimal('18.3333')),
#  ('Kenya', Decimal('86.70500000'), Decimal('49.5000')),
#  ('Kiribati', Decimal('0.18333333'), Decimal('0.0000')),
#  ('Kuwait', Decimal('120.84000000'), Decimal('4.0000')),
#  ('Kyrgyzstan', None, None),
#  ("Lao People's Democratic Republic", None, None),
#  ('Lebanon', Decimal('48.77833333'), Decimal('6.0000')),
#  ('Lesotho', Decimal('2.33500000'), Decimal('2.0000')),
#  ('Liberia', Decimal('3.30000000'), Decimal('5.0000')),
#  ('Libya', Decimal('60.34666667'), Decimal('6.3333')),
#  ('Madagascar', Decimal('12.87666667'), Decimal('26.6667')),
#  ('Malawi', Decimal('8.97166667'), Decimal('18.0000')),
#  ('Malaysia', Decimal('330.50500000'), Decimal('32.1667')),
#  ('Maldives', Decimal('4.65000000'), Decimal('0.3333')),
#  ('Mali', Decimal('15.72000000'), Decimal('19.6667')),
#  ('Marshall Islands', Decimal('0.21333333'), Decimal('0.0000')),
#  ('Martinique', None, None),
#  ('Mauritania', Decimal('7.22000000'), Decimal('4.0000')),
#  ('Mauritius', Decimal('13.14833333'), Decimal('1.0000')),
#  ('Mayotte', None, None),
#  ('Mexico', Decimal('1165.20166667'), Decimal('123.3333')),
#  ('Micronesia (Federated States of)', None, None),
#  ('Mongolia', Decimal('12.49666667'), Decimal('3.0000')),
#  ('Montserrat', None, None),
#  ('Morocco', Decimal('119.68833333'), Decimal('35.8333')),
#  ('Mozambique', Decimal('14.23000000'), Decimal('29.0000')),
#  ('Myanmar', Decimal('66.59333333'), Decimal('52.3333')),
#  ('Namibia', Decimal('11.96000000'), Decimal('2.0000')),
#  ('Nauru', Decimal('0.10833333'), Decimal('0.0000')),
#  ('Nepal', Decimal('29.76333333'), Decimal('28.5000')),
#  ('New Caledonia', Decimal('9.22666667'), Decimal('0.0000')),
#  ('New Zealand', Decimal('201.77166667'), Decimal('5.0000')),
#  ('Nicaragua', Decimal('13.01000000'), Decimal('6.5000')),
#  ('Niger', Decimal('11.79000000'), Decimal('22.1667')),
#  ('Nigeria', Decimal('429.24833333'), Decimal('195.8333')),
#  ('Niue', None, None),
#  ('Northern Mariana Islands', Decimal('1.23600000'), Decimal('0.0000')),
#  ('Oman', Decimal('81.69666667'), Decimal('4.6667')),
#  ('Pakistan', Decimal('316.81166667'), Decimal('218.5000')),
#  ('Palau', Decimal('0.28000000'), Decimal('0.0000')),
#  ('Panama', Decimal('60.01500000'), Decimal('4.0000')),
#  ('Papua New Guinea', Decimal('22.98833333'), Decimal('9.3333')),
#  ('Paraguay', Decimal('37.48166667'), Decimal('6.3333')),
#  ('Peru', Decimal('207.55833333'), Decimal('32.0000')),
#  ('Philippines', Decimal('339.82833333'), Decimal('107.6667')),
#  ('Puerto Rico', Decimal('103.38000000'), Decimal('3.0000')),
#  ('Qatar', Decimal('163.02500000'), Decimal('2.8333')),
#  ('Republic of Korea', None, None),
#  ('Réunion', None, None),
#  ('Rwanda', Decimal('9.44333333'), Decimal('12.5000')),
#  ('Saint Barthélemy', None, None),
#  ('Saint Helena', None, None),
#  ('Saint Kitts and Nevis', None, None),
#  ('Saint Lucia', None, None),
#  ('Saint Martin (French Part)', None, None),
#  ('Saint Pierre and Miquelon', None, None),
#  ('Saint Vincent and the Grenadines', None, None),
#  ('Samoa', Decimal('0.86666667'), Decimal('0.0000')),
#  ('Sao Tome and Principe', Decimal('0.39333333'), Decimal('0.0000')),
#  ('Saudi Arabia', Decimal('718.56166667'), Decimal('34.5000')),
#  ('Senegal', Decimal('21.47000000'), Decimal('15.3333')),
#  ('Seychelles', Decimal('1.56000000'), Decimal('0.0000')),
#  ('Sierra Leone', Decimal('3.97333333'), Decimal('7.6667')),
#  ('Singapore', Decimal('344.63166667'), Decimal('6.0000')),
#  ('Sint Maarten (Dutch part)', Decimal('1.23333333'), Decimal('0.0000')),
#  ('Solomon Islands', Decimal('1.49000000'), Decimal('1.0000')),
#  ('Somalia', Decimal('5.95000000'), Decimal('15.1667')),
#  ('South Africa', Decimal('363.67666667'), Decimal('57.1667')),
#  ('South Sudan', Decimal('12.00000000'), Decimal('10.6667')),
#  ('Sri Lanka', Decimal('89.39666667'), Decimal('21.5000')),
#  ('State of Palestine', None, None),
#  ('Sudan', Decimal('68.22500000'), Decimal('41.1667')),
#  ('Suriname', Decimal('3.82833333'), Decimal('1.0000')),
#  ('Syrian Arab Republic', Decimal('16.71833333'), Decimal('19.5000')),
#  ('Tajikistan', Decimal('7.83333333'), Decimal('9.1667')),
#  ('Thailand', Decimal('470.25666667'), Decimal('70.8333')),
#  ('Timor-Leste', Decimal('1.76500000'), Decimal('1.0000')),
#  ('Togo', Decimal('6.41833333'), Decimal('7.8333')),
#  ('Tokelau', None, None),
#  ('Tonga', Decimal('0.46666667'), Decimal('0.0000')),
#  ('Trinidad and Tobago', Decimal('23.89666667'), Decimal('1.5000')),
#  ('Tunisia', Decimal('43.24000000'), Decimal('12.0000')),
#  ('Türkiye', None, None),
#  ('Turkmenistan', Decimal('39.18000000'), Decimal('6.0000')),
#  ('Turks and Caicos Islands', Decimal('1.02500000'), Decimal('0.0000')),
#  ('Tuvalu', Decimal('0.04833333'), Decimal('0.0000')),
#  ('Uganda', Decimal('33.03500000'), Decimal('40.8333')),
#  ('United Arab Emirates', Decimal('387.42833333'), Decimal('9.0000')),
#  ('United Republic of Tanzania', None, None),
#  ('United States of America', None, None),
#  ('United States Virgin Islands', None, None),
#  ('Uruguay', Decimal('59.00833333'), Decimal('3.0000')),
#  ('Uzbekistan', Decimal('67.80833333'), Decimal('32.6667')),
#  ('Vanuatu', Decimal('0.85666667'), Decimal('0.0000')),
#  ('Venezuela (Bolivarian Republic of)', None, None),
#  ('Viet Nam', None, None),
#  ('Wallis and Futuna Islands', None, None),
#  ('Yemen', None, None),
#  ('Zambia', Decimal('22.63500000'), Decimal('17.5000')),
#  ('Zimbabwe', Decimal('22.59833333'), Decimal('14.8333'))]

# %% [markdown]
# ### Combining the queries
#
# Using the query and the subquery, determine the average GDP and population for countries with unemployment rates above 5%. Group the results by `Country_name`.

# %%
# %%sql
#
# SELECT
#     sub.Country_name,
#     AVG(sub.Est_gdp_in_billions) AS Avg_GDP,
#     AVG(sub.Est_population_in_millions) AS Avg_Population
# FROM (
#     SELECT
#         Country_name,
#         Est_gdp_in_billions,
#         Est_population_in_millions
#     FROM
#         Economic_Indicators
#     WHERE
#         Pct_unemployment > 5
#         AND Time_period = 2020
# ) AS sub
# GROUP BY
#     sub.Country_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 37 rows affected.
# [('Afghanistan', Decimal('20.14000000'), Decimal('39.0000')),
#  ('Argentina', Decimal('385.54000000'), Decimal('45.0000')),
#  ('Armenia', Decimal('12.64000000'), Decimal('3.0000')),
#  ('Australia', Decimal('1326.90000000'), Decimal('26.0000')),
#  ('Azerbaijan', Decimal('42.69000000'), Decimal('10.0000')),
#  ('Bhutan', Decimal('2.33000000'), Decimal('1.0000')),
#  ('Botswana', Decimal('14.93000000'), Decimal('3.0000')),
#  ('Brazil', Decimal('1448.56000000'), Decimal('213.0000')),
#  ('Brunei Darussalam', Decimal('12.01000000'), Decimal('0.0000')),
#  ('Canada', Decimal('1645.42000000'), Decimal('38.0000')),
#  ('Chile', Decimal('252.73000000'), Decimal('19.0000')),
#  ('China', Decimal('14687.67000000'), Decimal('1411.0000')),
#  ('Colombia', Decimal('270.30000000'), Decimal('51.0000')),
#  ('Costa Rica', Decimal('62.16000000'), Decimal('5.0000')),
#  ('Cyprus', Decimal('25.01000000'), Decimal('1.0000')),
#  ('Dominican Republic', Decimal('78.84000000'), Decimal('11.0000')),
#  ('Ecuador', Decimal('99.29000000'), Decimal('18.0000')),
#  ('El Salvador', Decimal('24.56000000'), Decimal('6.0000')),
#  ('Georgia', Decimal('15.84000000'), Decimal('4.0000')),
#  ('Honduras', Decimal('23.83000000'), Decimal('10.0000')),
#  ('India', Decimal('2667.69000000'), Decimal('1396.0000')),
#  ('Jamaica', Decimal('13.81000000'), Decimal('3.0000')),
#  ('Jordan', Decimal('44.18000000'), Decimal('11.0000')),
#  ('Kiribati', Decimal('0.18000000'), Decimal('0.0000')),
#  ('Mauritius', Decimal('11.40000000'), Decimal('1.0000')),
#  ('Mongolia', Decimal('13.31000000'), Decimal('3.0000')),
#  ('New Caledonia', Decimal('9.44000000'), Decimal('0.0000')),
#  ('Panama', Decimal('53.98000000'), Decimal('4.0000')),
#  ('Paraguay', Decimal('35.43000000'), Decimal('7.0000')),
#  ('Peru', Decimal('201.71000000'), Decimal('33.0000')),
#  ('Rwanda', Decimal('10.18000000'), Decimal('13.0000')),
#  ('Saudi Arabia', Decimal('703.37000000'), Decimal('36.0000')),
#  ('South Africa', Decimal('337.62000000'), Decimal('59.0000')),
#  ('Sri Lanka', Decimal('85.35000000'), Decimal('22.0000')),
#  ('Uruguay', Decimal('53.56000000'), Decimal('3.0000')),
#  ('Uzbekistan', Decimal('59.89000000'), Decimal('34.0000')),
#  ('Zambia', Decimal('18.11000000'), Decimal('19.0000'))]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Creating the subquery

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Est_gdp_in_billions,
#     Est_population_in_millions
# FROM
#     Economic_Indicators
# WHERE
#     Pct_unemployment > 5
#     AND Time_period = 2020;

# %% [markdown]
# This table simply filters the `Economic_Indicators` table to only display countries with unemployment > 5. This is the input table the main query will use.

# %% [markdown]
# ### Creating the main query

# %%
# %%sql
#
# SELECT
#     Country_name,
#     AVG(Est_gdp_in_billions) AS Avg_GDP,
#     AVG(Est_population_in_millions) AS Avg_Population
# FROM
#     Economic_Indicators
# GROUP BY
#     Country_name;

# %% [markdown]
# Note that this query calculates the averages for **all** years, and for **all** countries.

# %% [markdown]
# ### Combining the queries

# %%
# %%sql
#
# SELECT
#     Country_name,
#     AVG(Est_gdp_in_billions) AS Avg_GDP,
#     AVG(Est_population_in_millions) AS Avg_Population
# FROM
#     (SELECT
#         Country_name,
#         Est_gdp_in_billions,
#         Est_population_in_millions
#     FROM
#         Economic_Indicators
#     WHERE
#         Pct_unemployment > 5
#         AND Time_period = 2020) AS FilteredCountries
# GROUP BY
#     Country_name;

# %% [markdown]
# Using the subquery filters the data first into a derived table, which the main query uses to aggregate with.

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lesson, we used a subquery to determine the average GDP and populations of countries where the unemployment rate is above 5%. We made use of the `FROM` clause. In essence, the subquery in the `FROM` clause can be thought of as creating an intermediate or derived table for the main query to operate upon, even if this table exists only for the duration of the query execution.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
